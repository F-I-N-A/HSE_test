# %%
# Часть 1

import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Тестовое задание - tz_data.csv')
data.head()
# Out:
#           area  cluster cluster_name                     keyword  good (1)  \
# 0  eligibility      0.0    Кластер 0     several animated buried       1.0
# 1  eligibility      0.0    Кластер 0      singles unusual buyers       1.0
# 2  eligibility      0.0    Кластер 0          hawaiian directive       1.0
# 3  eligibility      0.0    Кластер 0           dynamics directly       1.0
# 4  eligibility      1.0    Кластер 1  decision surgeons montreal       1.0
#
#   count          x                   y
# 0  1260   5.772342  12.564796257345005
# 1   866  14.829280  7.8507285727125815
# 2   163  11.381856  3.8981370219558604
# 3  1146   9.980149   6.281427914064545
# 4   823   3.283940    4.39674063521296

# %%
data = data.drop(['good (1)'], axis=1)

# %%
data = data.dropna()

# %%
data = data.drop_duplicates(subset=['area', 'keyword'])

# %%
data['i'] = range(len(data))
data = data.set_index('i')

# %%
for i in range(len(data)):
    if not data['count'][i].isdigit():
        data = data.drop(labels = [i], axis = 0)

# %%
data['count'] = data['count'].astype(int)

# %%
data['i'] = range(len(data))
data = data.set_index('i')

# %%
colors = ['#17becf', '#bcbd22', '#7f7f7f', '#e377c2', '#8c564b', '#9467bd', '#d62728', '#2ca02c', '#ff7f0e', '#1f77b4']
data['color'] = ''
c = 0
data.loc[0, 'color'] = colors[c] 

for i in range(1, len(data)):
    if data['area'][i] == data['area'][i - 1] and data['cluster'][i] == data['cluster'][i - 1]:
        data.loc[i, 'color'] = colors[c]
    elif data['area'][i] == data['area'][i - 1] and data['cluster'][i] != data['cluster'][i - 1]:
        c += 1
        data.loc[i, 'color'] = colors[c]
    elif data['area'][i] != data['area'][i - 1]:
        c = 0
        data.loc[i, 'color'] = colors[c]

# %%
data = data.sort_values(by=['area', 'cluster', 'cluster_name', 'count'], ascending = [True, True, True, False])
data
# Out:
#        area  cluster cluster_name                             keyword  count  \
# i
# 103   ar\vr      0.0    Кластер 0           written conflict fabulous   1443
# 105   ar\vr      0.0    Кластер 0                reservations linking    751
# 104   ar\vr      0.0    Кластер 0                  interfaces neutral    586
# 106   ar\vr      0.0    Кластер 0                 committees parallel    173
# 107   ar\vr      1.0    Кластер 1  postcards looked republic detector   1397
# ..      ...      ...          ...                                 ...    ...
# 97   worlds      2.0    Кластер 2                   ringtone parental    471
# 99   worlds      2.0    Кластер 2                   recipient traffic    236
# 102  worlds      3.0    Кластер 3                   immunology plates   1653
# 100  worlds      3.0    Кластер 3                     holdings herbal   1476
# 101  worlds      3.0    Кластер 3                    exchanges castle   1097
#
#              x                   y    color
# i
# 103   2.991167   7.106798807182176  #17becf
# 105  10.195602  12.259495712252914  #17becf
# 104  10.443533  13.809914970161072  #17becf
# 106   6.735260   3.613982972088637  #17becf
# 107  10.474474   6.220011967033064  #bcbd22
# ..         ...                 ...      ...
# 97   11.723895   4.363994491947961  #7f7f7f
# 99    5.593629  0.5533676310113189  #7f7f7f
# 102   2.407028    7.65152738334079  #e377c2
# 100   3.986508  10.906339823131932  #e377c2
# 101   8.082231   6.587932953846258  #e377c2
#
# [218 rows x 8 columns]

# %%
writer = pd.ExcelWriter('output.xlsx')
data.to_excel(writer)
writer.save()

# %%
# Часть 2

areas = list(data.area.unique())

for a in areas:
    df = data[data['area'] == a]
    title = 'Диаграмма рассеяния по области '+ a

    fig, ax = plt.subplots(figsize=(12,6))
    plt.scatter(df['x'], df['y'], c=df['color'],
                   marker = 'o',
                   edgecolors = 'black',
                   alpha = 0.8)
    ax.set_title(title)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    
    ax.legend()

    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
